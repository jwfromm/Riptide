# %%
import tensorflow as tf
import numpy as np
import tensorflow.keras.layers as nn
import os
from slim.preprocessing.cifarnet_preprocessing import preprocess_image

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
@tf.custom_gradient
def AlphaClip(x, alpha):
    output = tf.clip_by_value(x, 0, alpha)

    def grad_fn(dy):
        x_grad_mask = tf.cast(tf.logical_and(x >= 0, x <= alpha), tf.float32)
        alpha_grad_mask = tf.cast(x >= alpha, tf.float32)
        alpha_grad = tf.reduce_sum(dy * alpha_grad_mask)
        x_grad = dy * x_grad_mask
        
        return [x_grad, alpha_grad]

    return output, grad_fn

@tf.custom_gradient
def AlphaQuantize(x, alpha, bits):
    output = tf.round(x * ((2**bits - 1) / alpha)) * (alpha / (2**bits - 1))
    
    def grad_fn(dy):
        return [dy, None, None]
    
    return output, grad_fn

class PACT(tf.keras.layers.Layer):
    def __init__(self, quantize=False, bits=2.):
        super(PACT, self).__init__()      
        self.quantize = quantize
        self.bits = bits
        
    def build(self, input_shape):
        self.alpha = self.add_variable(
            'alpha', shape=[], 
            initializer=tf.keras.initializers.Constant([10.], dtype=tf.float32),
            #regularizer=tf.keras.regularizers.l2(0.01))
            regularizer = tf.keras.regularizers.l2(0.0002))
        
    def call(self, inputs):
        outputs = AlphaClip(inputs, self.alpha)
        if self.quantize:
            with tf.name_scope('QA'):
                outputs = AlphaQuantize(outputs, self.alpha, self.bits)
                tf.summary.histogram('activation', inputs)
                tf.summary.histogram('quantized_activation', outputs)
        return outputs
    
    def get_config(self):
        return {'quantize': self.quantize, 'bits': self.bits}
    
    def compute_output_shape(self, input_shape):
        return input_shape

# %%
def get_sawb_coefficients(bits):
    bits = int(bits)
    assert bits <= 4, "Currently only supports bitwidths up to 4."
    coefficient_dict = {1: [0., 1.], 2: [3.19, -2.14], 3: [7.40, -6.66], 4: [11.86, -11.68]}
    return coefficient_dict[bits]

@tf.custom_gradient
def SAWBQuantize(x, alpha, bits):
    # Clip between -alpha and alpha
    clipped = tf.clip_by_value(x, -alpha, alpha)
    # Rescale to [0, alpha]
    scaled = (clipped + alpha) / 2.
    # Quantize.
    quantized = tf.round(scaled * ((2**bits - 1) / alpha)) * (alpha / (2**bits - 1))
    # Rescale to negative range.
    output = (2 * quantized) - alpha
    
    def grad_fn(dy):
        return [dy, None, None]
    return output, grad_fn

class SAWBConv2D(tf.keras.layers.Conv2D):
    def __init__(self, *args, bits=2., **kwargs):
        super(SAWBConv2D, self).__init__(*args, **kwargs)
        self.bits = float(bits)
        self.c1, self.c2 = get_sawb_coefficients(bits)
        self.alpha = None
        
    def call(self, inputs):
        # Compute proper scale for our weights.
        alpha = self.c1 * tf.sqrt(tf.reduce_mean(self.kernel**2)) + self.c2 * tf.reduce_mean(tf.abs(self.kernel))
        self.alpha = alpha
        # Quantize kernel
        with tf.name_scope("QW"):
            q_kernel = SAWBQuantize(self.kernel, alpha, self.bits)
            tf.summary.histogram("weight", self.kernel)
            tf.summary.histogram("quantized_weight", q_kernel)
        
        # Invoke convolution
        outputs = self._convolution_op(inputs, q_kernel)
        
        if self.use_bias:
            if self.data_format == 'channels_first':
                outputs = tf.nn.bias_add(
                    outputs, self.bias, data_format='NCHW')
            else:
                outputs = tf.nn.bias_add(
                    outputs, self.bias, data_format='NHWC')

        if self.activation is not None:
            outputs = self.activation(outputs)

        return outputs

# %%
def preprocess(image, label):
    image = tf.image.resize_image_with_crop_or_pad(image, 40, 40)
    image = tf.random_crop(image, [32, 32, 3])
    image = tf.image.random_flip_left_right(image)
    return image, label

# %%
batch_size = 128
(train_data, train_labels), (test_data, test_labels) = tf.keras.datasets.cifar10.load_data()

train_labels = train_labels.astype(np.int32)
test_labels = test_labels.astype(np.int32)

def train_transform(data, label):
    data = preprocess_image(data, 32, 32, is_training=True)
    return data, label

def test_transform(data, label):
    data = preprocess_image(data, 32, 32, is_training=False)
    return data, label

def train_input_fn():
    ds = tf.data.Dataset.from_tensor_slices((train_data, train_labels))
    ds = ds.prefetch(batch_size)
    ds = ds.shuffle(10000)
    ds = ds.repeat()
    ds = ds.map(train_transform, num_parallel_calls=4)
    ds = ds.batch(batch_size)
    ds = ds.prefetch(buffer_size=tf.contrib.data.AUTOTUNE)
    return ds

def test_input_fn():
    ds = tf.data.Dataset.from_tensor_slices((test_data, test_labels))
    ds = ds.map(test_transform, num_parallel_calls=4)
    ds = ds.batch(batch_size)
    ds = ds.repeat(1)
    return ds

# %%
cfg = {
    'VGG11': [64, 'M', 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'VGG13': [64, 64, 'M', 128, 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'VGG16': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M'],
    'VGG19': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 256, 'M', 512, 512, 512, 512, 'M', 512, 512, 512, 512, 'M'],
}

class VGG(tf.keras.models.Model):
    def __init__(self, name, *args, **kwargs):
        super(VGG, self).__init__(*args, **kwargs)
        self.reg = tf.keras.regularizers.l2(0.0002)
        self.features = self._make_layers(cfg[name])
        self.flatten = nn.Flatten()
        self.classifier = nn.Dense(10, activation=None, kernel_regularizer=self.reg)
    
    def call(self, inputs, training=True):
        features = self.features(inputs, training=training)
        features = self.flatten(features)
        output = self.classifier(features)
        
        return output
    
    def _make_layers(self, cfg):
        layers = [nn.Conv2D(cfg[0], kernel_size=3, padding='same', kernel_regularizer=self.reg), nn.BatchNormalization(), nn.Activation('relu')]#PACT(quantize=True)]
        for x in cfg[1:]:
            if x == 'M':
                layers += [nn.MaxPool2D(pool_size=2, strides=2)]
            else:
                layers += [nn.Conv2D(x, kernel_size=3, padding='same'),
                           #SAWBConv2D(x, kernel_size=3, padding='same', kernel_regularizer=self.reg),
                           nn.BatchNormalization(),
                           #PACT(quantize=True)]
                           nn.Activation('relu')]
        layers += [nn.GlobalAveragePooling2D()]
        
        return tf.keras.models.Sequential(layers)

# %%
def model_fn(features, labels, mode):
    tf.summary.image('images', features, max_outputs=4)
    model = VGG('VGG11')
    
    is_training = (mode == tf.estimator.ModeKeys.TRAIN)
    
    logits = model(features, training=is_training)
    
    predictions = {
        'classes': tf.argmax(input=logits, axis=1),
        'probabilities': tf.nn.softmax(logits, name='softmax_tensor')
    }
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode=mode, predictions=predictions)
    
    # Cacluate loss for train and eval.
    cross_entropy = tf.losses.sparse_softmax_cross_entropy(labels=labels, logits=logits)
    reg_losses = model.get_losses_for(None) + model.get_losses_for(features)
    loss = cross_entropy
    if reg_losses:
        loss += tf.math.add_n(reg_losses)
    # Log losses.
    tf.summary.scalar('loss', loss)
    
    # Compute training metrics.
    accuracy = tf.metrics.accuracy(labels, predictions['classes'])
    metrics = {'accuracy': accuracy}
    
    # Set up eval mode spec.
    if mode == tf.estimator.ModeKeys.EVAL:
        return tf.estimator.EstimatorSpec(mode=mode, loss=loss, eval_metric_ops=metrics)
    
    # Otherwise we're doing training.
    global_step = tf.train.get_or_create_global_step()
    #optimizer = tf.train.AdamOptimizer()
    learning_rate = tf.train.exponential_decay(0.1, global_step, 60*NUM_STEPS, 0.1, staircase=True)
    tf.summary.scalar('lr', learning_rate)
    optimizer = tf .train.MomentumOptimizer(learning_rate, 0.9)
    update_ops = model.get_updates_for(features) + model.get_updates_for(None)
    with tf.control_dependencies(update_ops):
        train_op = optimizer.minimize(loss=loss, var_list=model.trainable_variables, global_step=global_step)
    # Keep track of training accuracy.
    tf.summary.scalar('train_accuracy', accuracy[1])
    
    # Log alpha histograms.
    for var in model.trainable_variables:
        if 'alpha' in var.name:
            tf.summary.histogram(var.name, var)
    
    return tf.estimator.EstimatorSpec(
        mode=mode, loss=loss, train_op=train_op, eval_metric_ops=metrics)

# %%
experiment_name = 'vgg_baseline_full'
model_path = os.path.join('/data', 'jwfromm', 'cifar_models', experiment_name)

classifier = tf.estimator.Estimator(
    model_fn=model_fn, model_dir=model_path)

NUM_STEPS = np.ceil(len(train_data)/batch_size)
EPOCHS = 200

train_spec = tf.estimator.TrainSpec(
    input_fn=train_input_fn, max_steps=NUM_STEPS * EPOCHS)
eval_spec = tf.estimator.EvalSpec(input_fn=test_input_fn)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '/data/jwfromm/cifar_models/vgg_baseline_full', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f2f190e6048>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
tf.estimator.train_and_evaluate(classifier, train_spec, eval_spec)
# Out:
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 600.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /data/jwfromm/cifar_models/vgg_baseline_full/model.ckpt.
# INFO:tensorflow:loss = 3.1842318, step = 0
# INFO:tensorflow:global_step/sec: 33.9306
# INFO:tensorflow:loss = 2.4029074, step = 100 (2.948 sec)
# INFO:tensorflow:global_step/sec: 48.6628
# INFO:tensorflow:loss = 2.373904, step = 200 (2.055 sec)
# INFO:tensorflow:global_step/sec: 48.9751
# INFO:tensorflow:loss = 2.3737335, step = 300 (2.042 sec)
# INFO:tensorflow:global_step/sec: 47.9858
# INFO:tensorflow:loss = 2.3476462, step = 400 (2.084 sec)
# INFO:tensorflow:global_step/sec: 48.9153
# INFO:tensorflow:loss = 2.3360934, step = 500 (2.044 sec)
# INFO:tensorflow:global_step/sec: 48.6261
# INFO:tensorflow:loss = 2.3247132, step = 600 (2.056 sec)
# INFO:tensorflow:global_step/sec: 48.6349
# INFO:tensorflow:loss = 2.230959, step = 700 (2.056 sec)
# INFO:tensorflow:global_step/sec: 48.5057
# INFO:tensorflow:loss = 2.225823, step = 800 (2.062 sec)
# INFO:tensorflow:global_step/sec: 48.559
# INFO:tensorflow:loss = 2.062936, step = 900 (2.061 sec)
# INFO:tensorflow:global_step/sec: 48.7473
# INFO:tensorflow:loss = 2.1424105, step = 1000 (2.049 sec)
# INFO:tensorflow:global_step/sec: 48.8707
# INFO:tensorflow:loss = 2.040991, step = 1100 (2.047 sec)
# INFO:tensorflow:global_step/sec: 48.4592
# INFO:tensorflow:loss = 2.1232855, step = 1200 (2.064 sec)
# INFO:tensorflow:global_step/sec: 48.5903
# INFO:tensorflow:loss = 1.893848, step = 1300 (2.058 sec)
# INFO:tensorflow:global_step/sec: 48.8323
# INFO:tensorflow:loss = 1.8141303, step = 1400 (2.048 sec)
# INFO:tensorflow:global_step/sec: 48.8708
# INFO:tensorflow:loss = 1.8706491, step = 1500 (2.047 sec)
# INFO:tensorflow:global_step/sec: 48.1828
# INFO:tensorflow:loss = 1.7852944, step = 1600 (2.075 sec)
# INFO:tensorflow:global_step/sec: 48.7821
# INFO:tensorflow:loss = 1.7555786, step = 1700 (2.049 sec)
# INFO:tensorflow:global_step/sec: 48.6914
# INFO:tensorflow:loss = 1.76248, step = 1800 (2.054 sec)
# INFO:tensorflow:global_step/sec: 48.9133
# INFO:tensorflow:loss = 1.548425, step = 1900 (2.044 sec)
# INFO:tensorflow:global_step/sec: 48.5903
# INFO:tensorflow:loss = 1.5928752, step = 2000 (2.058 sec)
# INFO:tensorflow:global_step/sec: 48.7817
# INFO:tensorflow:loss = 1.3875926, step = 2100 (2.050 sec)
# INFO:tensorflow:global_step/sec: 48.3837
# INFO:tensorflow:loss = 1.4181046, step = 2200 (2.067 sec)
# INFO:tensorflow:global_step/sec: 48.5713
# INFO:tensorflow:loss = 1.3356117, step = 2300 (2.058 sec)
# INFO:tensorflow:global_step/sec: 48.4503
# INFO:tensorflow:loss = 1.4331868, step = 2400 (2.064 sec)
# INFO:tensorflow:global_step/sec: 48.4566
# INFO:tensorflow:loss = 1.40047, step = 2500 (2.064 sec)
# INFO:tensorflow:global_step/sec: 48.5372
# INFO:tensorflow:loss = 1.3723875, step = 2600 (2.060 sec)
# INFO:tensorflow:global_step/sec: 48.4625
# INFO:tensorflow:loss = 1.183882, step = 2700 (2.063 sec)
# INFO:tensorflow:global_step/sec: 48.4224
# INFO:tensorflow:loss = 1.0640731, step = 2800 (2.065 sec)
# INFO:tensorflow:global_step/sec: 48.4477
# INFO:tensorflow:loss = 1.1545057, step = 2900 (2.065 sec)
# INFO:tensorflow:global_step/sec: 48.2624
# INFO:tensorflow:loss = 1.0979389, step = 3000 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.5164
# INFO:tensorflow:loss = 1.1615038, step = 3100 (2.060 sec)
# INFO:tensorflow:global_step/sec: 48.5256
# INFO:tensorflow:loss = 1.1397903, step = 3200 (2.061 sec)
# INFO:tensorflow:global_step/sec: 48.565
# INFO:tensorflow:loss = 1.0678655, step = 3300 (2.059 sec)
# INFO:tensorflow:global_step/sec: 48.7063
# INFO:tensorflow:loss = 1.068821, step = 3400 (2.053 sec)
# INFO:tensorflow:global_step/sec: 48.8681
# INFO:tensorflow:loss = 0.81635624, step = 3500 (2.047 sec)
# INFO:tensorflow:global_step/sec: 48.4769
# INFO:tensorflow:loss = 1.0695044, step = 3600 (2.063 sec)
# INFO:tensorflow:global_step/sec: 48.5148
# INFO:tensorflow:loss = 0.8773962, step = 3700 (2.061 sec)
# INFO:tensorflow:global_step/sec: 48.4202
# INFO:tensorflow:loss = 0.93446183, step = 3800 (2.065 sec)
# INFO:tensorflow:global_step/sec: 48.3991
# INFO:tensorflow:loss = 1.0119405, step = 3900 (2.066 sec)
# INFO:tensorflow:global_step/sec: 48.4132
# INFO:tensorflow:loss = 0.8394674, step = 4000 (2.066 sec)
# INFO:tensorflow:global_step/sec: 48.649
# INFO:tensorflow:loss = 0.84082603, step = 4100 (2.055 sec)
# INFO:tensorflow:global_step/sec: 48.7576
# INFO:tensorflow:loss = 0.86455166, step = 4200 (2.051 sec)
# INFO:tensorflow:global_step/sec: 48.7154
# INFO:tensorflow:loss = 0.8664168, step = 4300 (2.053 sec)
# INFO:tensorflow:global_step/sec: 48.404
# INFO:tensorflow:loss = 1.1471939, step = 4400 (2.065 sec)
# INFO:tensorflow:global_step/sec: 48.6795
# INFO:tensorflow:loss = 0.7394292, step = 4500 (2.054 sec)
# INFO:tensorflow:global_step/sec: 48.4516
# INFO:tensorflow:loss = 0.85248053, step = 4600 (2.064 sec)
# INFO:tensorflow:global_step/sec: 48.1132
# INFO:tensorflow:loss = 0.83444375, step = 4700 (2.080 sec)
# INFO:tensorflow:global_step/sec: 48.3743
# INFO:tensorflow:loss = 0.77043563, step = 4800 (2.066 sec)
# INFO:tensorflow:global_step/sec: 48.4955
# INFO:tensorflow:loss = 0.67332906, step = 4900 (2.062 sec)
# INFO:tensorflow:global_step/sec: 48.2781
# INFO:tensorflow:loss = 0.9191301, step = 5000 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.4132
# INFO:tensorflow:loss = 0.6712371, step = 5100 (2.066 sec)
# INFO:tensorflow:global_step/sec: 48.319
# INFO:tensorflow:loss = 0.7623999, step = 5200 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.4866
# INFO:tensorflow:loss = 0.8795873, step = 5300 (2.063 sec)
# INFO:tensorflow:global_step/sec: 48.5348
# INFO:tensorflow:loss = 0.7358382, step = 5400 (2.060 sec)
# INFO:tensorflow:global_step/sec: 48.1655
# INFO:tensorflow:loss = 0.6620445, step = 5500 (2.076 sec)
# INFO:tensorflow:global_step/sec: 48.5784
# INFO:tensorflow:loss = 0.7549113, step = 5600 (2.058 sec)
# INFO:tensorflow:global_step/sec: 48.3061
# INFO:tensorflow:loss = 0.6134315, step = 5700 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.6324
# INFO:tensorflow:loss = 0.5578266, step = 5800 (2.056 sec)
# INFO:tensorflow:global_step/sec: 48.3182
# INFO:tensorflow:loss = 0.7487144, step = 5900 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.368
# INFO:tensorflow:loss = 0.5438521, step = 6000 (2.067 sec)
# INFO:tensorflow:global_step/sec: 48.6462
# INFO:tensorflow:loss = 0.7716702, step = 6100 (2.056 sec)
# INFO:tensorflow:global_step/sec: 48.5675
# INFO:tensorflow:loss = 0.73501086, step = 6200 (2.060 sec)
# INFO:tensorflow:global_step/sec: 48.2819
# INFO:tensorflow:loss = 0.6157794, step = 6300 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.1651
# INFO:tensorflow:loss = 0.54898864, step = 6400 (2.076 sec)
# INFO:tensorflow:global_step/sec: 48.2398
# INFO:tensorflow:loss = 0.5795051, step = 6500 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.5078
# INFO:tensorflow:loss = 0.63613707, step = 6600 (2.061 sec)
# INFO:tensorflow:global_step/sec: 48.2679
# INFO:tensorflow:loss = 0.7072998, step = 6700 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.5635
# INFO:tensorflow:loss = 0.68136215, step = 6800 (2.059 sec)
# INFO:tensorflow:global_step/sec: 48.4131
# INFO:tensorflow:loss = 0.5585743, step = 6900 (2.066 sec)
# INFO:tensorflow:global_step/sec: 48.5217
# INFO:tensorflow:loss = 0.55140907, step = 7000 (2.061 sec)
# INFO:tensorflow:global_step/sec: 48.3758
# INFO:tensorflow:loss = 0.57768005, step = 7100 (2.067 sec)
# INFO:tensorflow:global_step/sec: 48.3581
# INFO:tensorflow:loss = 0.43723935, step = 7200 (2.068 sec)
# INFO:tensorflow:global_step/sec: 48.2788
# INFO:tensorflow:loss = 0.51166046, step = 7300 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.2797
# INFO:tensorflow:loss = 0.54465085, step = 7400 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.175
# INFO:tensorflow:loss = 0.5747519, step = 7500 (2.076 sec)
# INFO:tensorflow:global_step/sec: 48.2486
# INFO:tensorflow:loss = 0.41250306, step = 7600 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.4892
# INFO:tensorflow:loss = 0.54563016, step = 7700 (2.062 sec)
# INFO:tensorflow:global_step/sec: 48.4749
# INFO:tensorflow:loss = 0.5125058, step = 7800 (2.064 sec)
# INFO:tensorflow:global_step/sec: 48.2129
# INFO:tensorflow:loss = 0.45270044, step = 7900 (2.076 sec)
# INFO:tensorflow:global_step/sec: 48.3632
# INFO:tensorflow:loss = 0.5603916, step = 8000 (2.065 sec)
# INFO:tensorflow:global_step/sec: 48.1543
# INFO:tensorflow:loss = 0.62702274, step = 8100 (2.077 sec)
# INFO:tensorflow:global_step/sec: 48.3119
# INFO:tensorflow:loss = 0.28357905, step = 8200 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.1731
# INFO:tensorflow:loss = 0.61738336, step = 8300 (2.075 sec)
# INFO:tensorflow:global_step/sec: 48.358
# INFO:tensorflow:loss = 0.39545804, step = 8400 (2.068 sec)
# INFO:tensorflow:global_step/sec: 48.3046
# INFO:tensorflow:loss = 0.5690638, step = 8500 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.2981
# INFO:tensorflow:loss = 0.58926284, step = 8600 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.2436
# INFO:tensorflow:loss = 0.53300446, step = 8700 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.4498
# INFO:tensorflow:loss = 0.41236475, step = 8800 (2.064 sec)
# INFO:tensorflow:global_step/sec: 48.194
# INFO:tensorflow:loss = 0.5045193, step = 8900 (2.075 sec)
# INFO:tensorflow:global_step/sec: 48.0506
# INFO:tensorflow:loss = 0.4512118, step = 9000 (2.081 sec)
# INFO:tensorflow:global_step/sec: 48.2521
# INFO:tensorflow:loss = 0.5698978, step = 9100 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.2854
# INFO:tensorflow:loss = 0.43350387, step = 9200 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.4013
# INFO:tensorflow:loss = 0.43665045, step = 9300 (2.066 sec)
# INFO:tensorflow:global_step/sec: 48.0236
# INFO:tensorflow:loss = 0.2888087, step = 9400 (2.082 sec)
# INFO:tensorflow:global_step/sec: 48.451
# INFO:tensorflow:loss = 0.4882591, step = 9500 (2.063 sec)
# INFO:tensorflow:global_step/sec: 48.2878
# INFO:tensorflow:loss = 0.4535357, step = 9600 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.5025
# INFO:tensorflow:loss = 0.479445, step = 9700 (2.062 sec)
# INFO:tensorflow:global_step/sec: 48.0059
# INFO:tensorflow:loss = 0.42940038, step = 9800 (2.083 sec)
# INFO:tensorflow:global_step/sec: 48.2288
# INFO:tensorflow:loss = 0.43452397, step = 9900 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.3836
# INFO:tensorflow:loss = 0.42216867, step = 10000 (2.067 sec)
# INFO:tensorflow:global_step/sec: 48.6443
# INFO:tensorflow:loss = 0.29351425, step = 10100 (2.056 sec)
# INFO:tensorflow:global_step/sec: 47.958
# INFO:tensorflow:loss = 0.4496955, step = 10200 (2.085 sec)
# INFO:tensorflow:global_step/sec: 48.4794
# INFO:tensorflow:loss = 0.43017203, step = 10300 (2.063 sec)
# INFO:tensorflow:global_step/sec: 48.3411
# INFO:tensorflow:loss = 0.44689918, step = 10400 (2.068 sec)
# INFO:tensorflow:global_step/sec: 48.3774
# INFO:tensorflow:loss = 0.35412863, step = 10500 (2.067 sec)
# INFO:tensorflow:global_step/sec: 48.2482
# INFO:tensorflow:loss = 0.4373687, step = 10600 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.4282
# INFO:tensorflow:loss = 0.28139657, step = 10700 (2.065 sec)
# INFO:tensorflow:global_step/sec: 48.1024
# INFO:tensorflow:loss = 0.37121624, step = 10800 (2.079 sec)
# INFO:tensorflow:global_step/sec: 48.2558
# INFO:tensorflow:loss = 0.31014404, step = 10900 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.0545
# INFO:tensorflow:loss = 0.43488884, step = 11000 (2.081 sec)
# INFO:tensorflow:global_step/sec: 48.2367
# INFO:tensorflow:loss = 0.34391168, step = 11100 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.2063
# INFO:tensorflow:loss = 0.34943724, step = 11200 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.1485
# INFO:tensorflow:loss = 0.4840894, step = 11300 (2.077 sec)
# INFO:tensorflow:global_step/sec: 48.3009
# INFO:tensorflow:loss = 0.39737785, step = 11400 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.2802
# INFO:tensorflow:loss = 0.3280506, step = 11500 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.3372
# INFO:tensorflow:loss = 0.39545825, step = 11600 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.1268
# INFO:tensorflow:loss = 0.28078815, step = 11700 (2.078 sec)
# INFO:tensorflow:global_step/sec: 48.3131
# INFO:tensorflow:loss = 0.34944487, step = 11800 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.3365
# INFO:tensorflow:loss = 0.39396676, step = 11900 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.1535
# INFO:tensorflow:loss = 0.38515028, step = 12000 (2.077 sec)
# INFO:tensorflow:global_step/sec: 48.3418
# INFO:tensorflow:loss = 0.28730333, step = 12100 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.1007
# INFO:tensorflow:loss = 0.4881581, step = 12200 (2.079 sec)
# INFO:tensorflow:global_step/sec: 48.4983
# INFO:tensorflow:loss = 0.36294192, step = 12300 (2.062 sec)
# INFO:tensorflow:global_step/sec: 48.3099
# INFO:tensorflow:loss = 0.40624425, step = 12400 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.2711
# INFO:tensorflow:loss = 0.30822158, step = 12500 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.0634
# INFO:tensorflow:loss = 0.28317088, step = 12600 (2.079 sec)
# INFO:tensorflow:global_step/sec: 48.1784
# INFO:tensorflow:loss = 0.44091836, step = 12700 (2.075 sec)
# INFO:tensorflow:global_step/sec: 48.3192
# INFO:tensorflow:loss = 0.2750247, step = 12800 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.1188
# INFO:tensorflow:loss = 0.2016093, step = 12900 (2.079 sec)
# INFO:tensorflow:global_step/sec: 48.4146
# INFO:tensorflow:loss = 0.5238312, step = 13000 (2.065 sec)
# INFO:tensorflow:global_step/sec: 48.4047
# INFO:tensorflow:loss = 0.237997, step = 13100 (2.067 sec)
# INFO:tensorflow:global_step/sec: 48.2645
# INFO:tensorflow:loss = 0.28153694, step = 13200 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.4169
# INFO:tensorflow:loss = 0.34758598, step = 13300 (2.065 sec)
# INFO:tensorflow:global_step/sec: 48.4947
# INFO:tensorflow:loss = 0.2953052, step = 13400 (2.063 sec)
# INFO:tensorflow:global_step/sec: 48.2355
# INFO:tensorflow:loss = 0.33343986, step = 13500 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.2293
# INFO:tensorflow:loss = 0.36160588, step = 13600 (2.073 sec)
# INFO:tensorflow:global_step/sec: 47.9193
# INFO:tensorflow:loss = 0.20771119, step = 13700 (2.087 sec)
# INFO:tensorflow:global_step/sec: 48.5662
# INFO:tensorflow:loss = 0.3795986, step = 13800 (2.058 sec)
# INFO:tensorflow:global_step/sec: 48.3895
# INFO:tensorflow:loss = 0.42112318, step = 13900 (2.066 sec)
# INFO:tensorflow:global_step/sec: 48.4379
# INFO:tensorflow:loss = 0.2818017, step = 14000 (2.065 sec)
# INFO:tensorflow:global_step/sec: 48.2749
# INFO:tensorflow:loss = 0.25521156, step = 14100 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.2346
# INFO:tensorflow:loss = 0.37241176, step = 14200 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.3878
# INFO:tensorflow:loss = 0.3824483, step = 14300 (2.066 sec)
# INFO:tensorflow:global_step/sec: 48.4684
# INFO:tensorflow:loss = 0.36342454, step = 14400 (2.064 sec)
# INFO:tensorflow:global_step/sec: 48.3676
# INFO:tensorflow:loss = 0.27616674, step = 14500 (2.068 sec)
# INFO:tensorflow:global_step/sec: 48.3295
# INFO:tensorflow:loss = 0.30475947, step = 14600 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.3357
# INFO:tensorflow:loss = 0.26891887, step = 14700 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.3564
# INFO:tensorflow:loss = 0.3624038, step = 14800 (2.068 sec)
# INFO:tensorflow:global_step/sec: 48.2101
# INFO:tensorflow:loss = 0.2604295, step = 14900 (2.075 sec)
# INFO:tensorflow:global_step/sec: 48.3849
# INFO:tensorflow:loss = 0.25541857, step = 15000 (2.066 sec)
# INFO:tensorflow:global_step/sec: 48.4645
# INFO:tensorflow:loss = 0.27305996, step = 15100 (2.064 sec)
# INFO:tensorflow:global_step/sec: 48.4297
# INFO:tensorflow:loss = 0.35870907, step = 15200 (2.065 sec)
# INFO:tensorflow:global_step/sec: 47.9135
# INFO:tensorflow:loss = 0.41288522, step = 15300 (2.087 sec)
# INFO:tensorflow:global_step/sec: 48.0931
# INFO:tensorflow:loss = 0.37123075, step = 15400 (2.079 sec)
# INFO:tensorflow:global_step/sec: 48.2455
# INFO:tensorflow:loss = 0.20944464, step = 15500 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.2705
# INFO:tensorflow:loss = 0.2457722, step = 15600 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.2137
# INFO:tensorflow:loss = 0.28332382, step = 15700 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.2366
# INFO:tensorflow:loss = 0.23034915, step = 15800 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.2597
# INFO:tensorflow:loss = 0.30828077, step = 15900 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.4745
# INFO:tensorflow:loss = 0.22820303, step = 16000 (2.063 sec)
# INFO:tensorflow:global_step/sec: 47.9945
# INFO:tensorflow:loss = 0.36051333, step = 16100 (2.083 sec)
# INFO:tensorflow:global_step/sec: 48.2546
# INFO:tensorflow:loss = 0.30146092, step = 16200 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.0386
# INFO:tensorflow:loss = 0.29080632, step = 16300 (2.082 sec)
# INFO:tensorflow:global_step/sec: 48.4017
# INFO:tensorflow:loss = 0.18614948, step = 16400 (2.066 sec)
# INFO:tensorflow:global_step/sec: 48.07
# INFO:tensorflow:loss = 0.30635557, step = 16500 (2.081 sec)
# INFO:tensorflow:global_step/sec: 48.3236
# INFO:tensorflow:loss = 0.31907937, step = 16600 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.5744
# INFO:tensorflow:loss = 0.15022583, step = 16700 (2.059 sec)
# INFO:tensorflow:global_step/sec: 48.4441
# INFO:tensorflow:loss = 0.25171927, step = 16800 (2.064 sec)
# INFO:tensorflow:global_step/sec: 47.8942
# INFO:tensorflow:loss = 0.217386, step = 16900 (2.088 sec)
# INFO:tensorflow:global_step/sec: 48.3694
# INFO:tensorflow:loss = 0.19064577, step = 17000 (2.067 sec)
# INFO:tensorflow:global_step/sec: 48.4366
# INFO:tensorflow:loss = 0.41409156, step = 17100 (2.065 sec)
# INFO:tensorflow:global_step/sec: 48.2522
# INFO:tensorflow:loss = 0.21724038, step = 17200 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.3646
# INFO:tensorflow:loss = 0.35973668, step = 17300 (2.068 sec)
# INFO:tensorflow:global_step/sec: 48.3152
# INFO:tensorflow:loss = 0.27215755, step = 17400 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.279
# INFO:tensorflow:loss = 0.23807143, step = 17500 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.2993
# INFO:tensorflow:loss = 0.28059918, step = 17600 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.3239
# INFO:tensorflow:loss = 0.28105158, step = 17700 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.336
# INFO:tensorflow:loss = 0.26596957, step = 17800 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.5436
# INFO:tensorflow:loss = 0.40179557, step = 17900 (2.061 sec)
# INFO:tensorflow:global_step/sec: 48.1718
# INFO:tensorflow:loss = 0.1880253, step = 18000 (2.075 sec)
# INFO:tensorflow:global_step/sec: 48.3332
# INFO:tensorflow:loss = 0.23284806, step = 18100 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.2925
# INFO:tensorflow:loss = 0.18354878, step = 18200 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.4217
# INFO:tensorflow:loss = 0.17089291, step = 18300 (2.065 sec)
# INFO:tensorflow:global_step/sec: 47.9765
# INFO:tensorflow:loss = 0.23726021, step = 18400 (2.085 sec)
# INFO:tensorflow:global_step/sec: 48.1017
# INFO:tensorflow:loss = 0.23964614, step = 18500 (2.078 sec)
# INFO:tensorflow:global_step/sec: 48.0745
# INFO:tensorflow:loss = 0.12216172, step = 18600 (2.080 sec)
# INFO:tensorflow:global_step/sec: 48.0763
# INFO:tensorflow:loss = 0.19110131, step = 18700 (2.081 sec)
# INFO:tensorflow:global_step/sec: 47.8606
# INFO:tensorflow:loss = 0.22445542, step = 18800 (2.089 sec)
# INFO:tensorflow:global_step/sec: 48.3189
# INFO:tensorflow:loss = 0.24302804, step = 18900 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.2212
# INFO:tensorflow:loss = 0.19957666, step = 19000 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.4648
# INFO:tensorflow:loss = 0.22420439, step = 19100 (2.063 sec)
# INFO:tensorflow:global_step/sec: 47.8599
# INFO:tensorflow:loss = 0.24232534, step = 19200 (2.089 sec)
# INFO:tensorflow:global_step/sec: 48.3635
# INFO:tensorflow:loss = 0.12932408, step = 19300 (2.068 sec)
# INFO:tensorflow:global_step/sec: 48.4305
# INFO:tensorflow:loss = 0.17427629, step = 19400 (2.065 sec)
# INFO:tensorflow:global_step/sec: 48.4112
# INFO:tensorflow:loss = 0.18162873, step = 19500 (2.065 sec)
# INFO:tensorflow:global_step/sec: 48.3422
# INFO:tensorflow:loss = 0.19359455, step = 19600 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.4397
# INFO:tensorflow:loss = 0.3149032, step = 19700 (2.065 sec)
# INFO:tensorflow:global_step/sec: 48.1385
# INFO:tensorflow:loss = 0.27963358, step = 19800 (2.077 sec)
# INFO:tensorflow:global_step/sec: 48.264
# INFO:tensorflow:loss = 0.18796018, step = 19900 (2.072 sec)
# INFO:tensorflow:global_step/sec: 47.9282
# INFO:tensorflow:loss = 0.30380353, step = 20000 (2.086 sec)
# INFO:tensorflow:global_step/sec: 48.5095
# INFO:tensorflow:loss = 0.18694225, step = 20100 (2.062 sec)
# INFO:tensorflow:global_step/sec: 48.3442
# INFO:tensorflow:loss = 0.15165955, step = 20200 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.3348
# INFO:tensorflow:loss = 0.18365759, step = 20300 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.2179
# INFO:tensorflow:loss = 0.17937008, step = 20400 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.2321
# INFO:tensorflow:loss = 0.21837209, step = 20500 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.0065
# INFO:tensorflow:loss = 0.16711383, step = 20600 (2.083 sec)
# INFO:tensorflow:global_step/sec: 48.2238
# INFO:tensorflow:loss = 0.20178011, step = 20700 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.0969
# INFO:tensorflow:loss = 0.24818869, step = 20800 (2.079 sec)
# INFO:tensorflow:global_step/sec: 48.1777
# INFO:tensorflow:loss = 0.21515347, step = 20900 (2.075 sec)
# INFO:tensorflow:global_step/sec: 48.4413
# INFO:tensorflow:loss = 0.16216953, step = 21000 (2.065 sec)
# INFO:tensorflow:global_step/sec: 48.2259
# INFO:tensorflow:loss = 0.23016313, step = 21100 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.3029
# INFO:tensorflow:loss = 0.1756573, step = 21200 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.5493
# INFO:tensorflow:loss = 0.22071336, step = 21300 (2.060 sec)
# INFO:tensorflow:global_step/sec: 48.3828
# INFO:tensorflow:loss = 0.24999785, step = 21400 (2.067 sec)
# INFO:tensorflow:global_step/sec: 47.9695
# INFO:tensorflow:loss = 0.26146227, step = 21500 (2.085 sec)
# INFO:tensorflow:global_step/sec: 48.3093
# INFO:tensorflow:loss = 0.18375124, step = 21600 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.1229
# INFO:tensorflow:loss = 0.14008725, step = 21700 (2.078 sec)
# INFO:tensorflow:global_step/sec: 48.366
# INFO:tensorflow:loss = 0.29113436, step = 21800 (2.067 sec)
# INFO:tensorflow:global_step/sec: 48.1742
# INFO:tensorflow:loss = 0.16112238, step = 21900 (2.076 sec)
# INFO:tensorflow:global_step/sec: 48.3104
# INFO:tensorflow:loss = 0.16216464, step = 22000 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.1969
# INFO:tensorflow:loss = 0.2738226, step = 22100 (2.075 sec)
# INFO:tensorflow:global_step/sec: 48.3116
# INFO:tensorflow:loss = 0.22644013, step = 22200 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.3045
# INFO:tensorflow:loss = 0.26121926, step = 22300 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.1399
# INFO:tensorflow:loss = 0.17974186, step = 22400 (2.077 sec)
# INFO:tensorflow:global_step/sec: 48.4016
# INFO:tensorflow:loss = 0.14870563, step = 22500 (2.067 sec)
# INFO:tensorflow:global_step/sec: 48.2591
# INFO:tensorflow:loss = 0.20324782, step = 22600 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.2758
# INFO:tensorflow:loss = 0.19080493, step = 22700 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.2321
# INFO:tensorflow:loss = 0.21563305, step = 22800 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.2397
# INFO:tensorflow:loss = 0.31614405, step = 22900 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.488
# INFO:tensorflow:loss = 0.13339256, step = 23000 (2.063 sec)
# INFO:tensorflow:global_step/sec: 48.3404
# INFO:tensorflow:loss = 0.19845742, step = 23100 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.2978
# INFO:tensorflow:loss = 0.12551159, step = 23200 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.3474
# INFO:tensorflow:loss = 0.11101206, step = 23300 (2.068 sec)
# INFO:tensorflow:global_step/sec: 48.4508
# INFO:tensorflow:loss = 0.26113808, step = 23400 (2.064 sec)
# INFO:tensorflow:global_step/sec: 48.1538
# INFO:tensorflow:loss = 0.1299563, step = 23500 (2.076 sec)
# INFO:tensorflow:global_step/sec: 48.5532
# INFO:tensorflow:loss = 0.12816733, step = 23600 (2.060 sec)
# INFO:tensorflow:global_step/sec: 48.2162
# INFO:tensorflow:loss = 0.0701496, step = 23700 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.2405
# INFO:tensorflow:loss = 0.12020977, step = 23800 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.1873
# INFO:tensorflow:loss = 0.11055788, step = 23900 (2.076 sec)
# INFO:tensorflow:global_step/sec: 48.3691
# INFO:tensorflow:loss = 0.103006504, step = 24000 (2.067 sec)
# INFO:tensorflow:global_step/sec: 48.2803
# INFO:tensorflow:loss = 0.075065866, step = 24100 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.2732
# INFO:tensorflow:loss = 0.087320395, step = 24200 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.2472
# INFO:tensorflow:loss = 0.046338394, step = 24300 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.457
# INFO:tensorflow:loss = 0.116709195, step = 24400 (2.064 sec)
# INFO:tensorflow:global_step/sec: 48.2116
# INFO:tensorflow:loss = 0.08256034, step = 24500 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.3545
# INFO:tensorflow:loss = 0.16150457, step = 24600 (2.068 sec)
# INFO:tensorflow:global_step/sec: 48.0282
# INFO:tensorflow:loss = 0.08405383, step = 24700 (2.082 sec)
# INFO:tensorflow:global_step/sec: 48.3353
# INFO:tensorflow:loss = 0.094625674, step = 24800 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.2955
# INFO:tensorflow:loss = 0.09941045, step = 24900 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.123
# INFO:tensorflow:loss = 0.05884943, step = 25000 (2.079 sec)
# INFO:tensorflow:global_step/sec: 48.1048
# INFO:tensorflow:loss = 0.09037092, step = 25100 (2.078 sec)
# INFO:tensorflow:global_step/sec: 48.2347
# INFO:tensorflow:loss = 0.047443397, step = 25200 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.2931
# INFO:tensorflow:loss = 0.071517035, step = 25300 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.1752
# INFO:tensorflow:loss = 0.067884415, step = 25400 (2.075 sec)
# INFO:tensorflow:global_step/sec: 48.2304
# INFO:tensorflow:loss = 0.063350365, step = 25500 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.3471
# INFO:tensorflow:loss = 0.06685083, step = 25600 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.4595
# INFO:tensorflow:loss = 0.07604675, step = 25700 (2.063 sec)
# INFO:tensorflow:global_step/sec: 47.952
# INFO:tensorflow:loss = 0.13574079, step = 25800 (2.086 sec)
# INFO:tensorflow:global_step/sec: 48.1331
# INFO:tensorflow:loss = 0.062162742, step = 25900 (2.077 sec)
# INFO:tensorflow:global_step/sec: 48.3529
# INFO:tensorflow:loss = 0.073278785, step = 26000 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.4427
# INFO:tensorflow:loss = 0.074784495, step = 26100 (2.064 sec)
# INFO:tensorflow:global_step/sec: 48.2543
# INFO:tensorflow:loss = 0.097595446, step = 26200 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.2445
# INFO:tensorflow:loss = 0.10967814, step = 26300 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.3148
# INFO:tensorflow:loss = 0.064808205, step = 26400 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.3455
# INFO:tensorflow:loss = 0.04636524, step = 26500 (2.067 sec)
# INFO:tensorflow:global_step/sec: 48.3075
# INFO:tensorflow:loss = 0.07443958, step = 26600 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.1391
# INFO:tensorflow:loss = 0.111341946, step = 26700 (2.077 sec)
# INFO:tensorflow:global_step/sec: 48.3612
# INFO:tensorflow:loss = 0.041483663, step = 26800 (2.068 sec)
# INFO:tensorflow:global_step/sec: 48.4067
# INFO:tensorflow:loss = 0.035612345, step = 26900 (2.066 sec)
# INFO:tensorflow:global_step/sec: 48.3363
# INFO:tensorflow:loss = 0.04046512, step = 27000 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.5557
# INFO:tensorflow:loss = 0.10536709, step = 27100 (2.060 sec)
# INFO:tensorflow:global_step/sec: 48.0814
# INFO:tensorflow:loss = 0.07003068, step = 27200 (2.080 sec)
# INFO:tensorflow:global_step/sec: 48.2623
# INFO:tensorflow:loss = 0.0773373, step = 27300 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.1232
# INFO:tensorflow:loss = 0.050381977, step = 27400 (2.078 sec)
# INFO:tensorflow:global_step/sec: 48.3628
# INFO:tensorflow:loss = 0.04088134, step = 27500 (2.068 sec)
# INFO:tensorflow:global_step/sec: 48.1998
# INFO:tensorflow:loss = 0.040689077, step = 27600 (2.075 sec)
# INFO:tensorflow:global_step/sec: 48.0737
# INFO:tensorflow:loss = 0.08323178, step = 27700 (2.080 sec)
# INFO:tensorflow:global_step/sec: 48.1566
# INFO:tensorflow:loss = 0.09058103, step = 27800 (2.076 sec)
# INFO:tensorflow:global_step/sec: 48.5709
# INFO:tensorflow:loss = 0.0684716, step = 27900 (2.059 sec)
# INFO:tensorflow:global_step/sec: 48.2146
# INFO:tensorflow:loss = 0.057903133, step = 28000 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.4576
# INFO:tensorflow:loss = 0.051908508, step = 28100 (2.064 sec)
# INFO:tensorflow:global_step/sec: 48.1552
# INFO:tensorflow:loss = 0.059972778, step = 28200 (2.076 sec)
# INFO:tensorflow:global_step/sec: 48.178
# INFO:tensorflow:loss = 0.046921432, step = 28300 (2.076 sec)
# INFO:tensorflow:global_step/sec: 48.4281
# INFO:tensorflow:loss = 0.055173256, step = 28400 (2.066 sec)
# INFO:tensorflow:global_step/sec: 48.3277
# INFO:tensorflow:loss = 0.07013757, step = 28500 (2.068 sec)
# INFO:tensorflow:global_step/sec: 48.2121
# INFO:tensorflow:loss = 0.10534398, step = 28600 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.1549
# INFO:tensorflow:loss = 0.08187941, step = 28700 (2.077 sec)
# INFO:tensorflow:global_step/sec: 48.4726
# INFO:tensorflow:loss = 0.038411967, step = 28800 (2.064 sec)
# INFO:tensorflow:Saving checkpoints for 28815 into /data/jwfromm/cifar_models/vgg_baseline_full/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-04-20:12:46
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /data/jwfromm/cifar_models/vgg_baseline_full/model.ckpt-28815
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Finished evaluation at 2019-04-04-20:12:47
# INFO:tensorflow:Saving dict for global step 28815: accuracy = 0.8819, global_step = 28815, loss = 0.5184631
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 28815: /data/jwfromm/cifar_models/vgg_baseline_full/model.ckpt-28815
# INFO:tensorflow:global_step/sec: 17.7218
# INFO:tensorflow:loss = 0.08651721, step = 28900 (5.644 sec)
# INFO:tensorflow:global_step/sec: 48.0205
# INFO:tensorflow:loss = 0.08316477, step = 29000 (2.081 sec)
# INFO:tensorflow:global_step/sec: 48.2725
# INFO:tensorflow:loss = 0.11472674, step = 29100 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.2316
# INFO:tensorflow:loss = 0.055259787, step = 29200 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.3643
# INFO:tensorflow:loss = 0.032877423, step = 29300 (2.068 sec)
# INFO:tensorflow:global_step/sec: 48.2742
# INFO:tensorflow:loss = 0.07005283, step = 29400 (2.071 sec)
# INFO:tensorflow:global_step/sec: 47.9013
# INFO:tensorflow:loss = 0.02799501, step = 29500 (2.087 sec)
# INFO:tensorflow:global_step/sec: 48.1379
# INFO:tensorflow:loss = 0.099137716, step = 29600 (2.078 sec)
# INFO:tensorflow:global_step/sec: 48.0949
# INFO:tensorflow:loss = 0.055749863, step = 29700 (2.079 sec)
# INFO:tensorflow:global_step/sec: 48.1849
# INFO:tensorflow:loss = 0.053267032, step = 29800 (2.075 sec)
# INFO:tensorflow:global_step/sec: 48.2385
# INFO:tensorflow:loss = 0.04560695, step = 29900 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.4506
# INFO:tensorflow:loss = 0.05984716, step = 30000 (2.064 sec)
# INFO:tensorflow:global_step/sec: 48.0564
# INFO:tensorflow:loss = 0.09120976, step = 30100 (2.081 sec)
# INFO:tensorflow:global_step/sec: 48.4544
# INFO:tensorflow:loss = 0.047376797, step = 30200 (2.064 sec)
# INFO:tensorflow:global_step/sec: 48.2344
# INFO:tensorflow:loss = 0.045522958, step = 30300 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.3045
# INFO:tensorflow:loss = 0.08813022, step = 30400 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.0014
# INFO:tensorflow:loss = 0.08497742, step = 30500 (2.084 sec)
# INFO:tensorflow:global_step/sec: 48.4622
# INFO:tensorflow:loss = 0.031383887, step = 30600 (2.063 sec)
# INFO:tensorflow:global_step/sec: 48.4423
# INFO:tensorflow:loss = 0.035085004, step = 30700 (2.064 sec)
# INFO:tensorflow:global_step/sec: 48.4843
# INFO:tensorflow:loss = 0.060401555, step = 30800 (2.062 sec)
# INFO:tensorflow:global_step/sec: 48.1549
# INFO:tensorflow:loss = 0.097122975, step = 30900 (2.077 sec)
# INFO:tensorflow:global_step/sec: 48.0248
# INFO:tensorflow:loss = 0.0596916, step = 31000 (2.082 sec)
# INFO:tensorflow:global_step/sec: 48.2885
# INFO:tensorflow:loss = 0.06317158, step = 31100 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.1938
# INFO:tensorflow:loss = 0.09605793, step = 31200 (2.075 sec)
# INFO:tensorflow:global_step/sec: 48.3429
# INFO:tensorflow:loss = 0.05107521, step = 31300 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.2584
# INFO:tensorflow:loss = 0.04287663, step = 31400 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.5507
# INFO:tensorflow:loss = 0.07794212, step = 31500 (2.060 sec)
# INFO:tensorflow:global_step/sec: 48.4667
# INFO:tensorflow:loss = 0.027387325, step = 31600 (2.063 sec)
# INFO:tensorflow:global_step/sec: 48.1818
# INFO:tensorflow:loss = 0.06916424, step = 31700 (2.076 sec)
# INFO:tensorflow:global_step/sec: 48.2676
# INFO:tensorflow:loss = 0.033346422, step = 31800 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.2971
# INFO:tensorflow:loss = 0.028830983, step = 31900 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.3461
# INFO:tensorflow:loss = 0.036293585, step = 32000 (2.068 sec)
# INFO:tensorflow:global_step/sec: 48.2289
# INFO:tensorflow:loss = 0.022943182, step = 32100 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.1801
# INFO:tensorflow:loss = 0.047201008, step = 32200 (2.075 sec)
# INFO:tensorflow:global_step/sec: 48.2845
# INFO:tensorflow:loss = 0.0783694, step = 32300 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.4313
# INFO:tensorflow:loss = 0.03314662, step = 32400 (2.065 sec)
# INFO:tensorflow:global_step/sec: 48.0009
# INFO:tensorflow:loss = 0.04400111, step = 32500 (2.083 sec)
# INFO:tensorflow:global_step/sec: 48.1796
# INFO:tensorflow:loss = 0.08883426, step = 32600 (2.076 sec)
# INFO:tensorflow:global_step/sec: 48.2608
# INFO:tensorflow:loss = 0.057828065, step = 32700 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.5584
# INFO:tensorflow:loss = 0.04323654, step = 32800 (2.059 sec)
# INFO:tensorflow:global_step/sec: 48.1086
# INFO:tensorflow:loss = 0.036076173, step = 32900 (2.079 sec)
# INFO:tensorflow:global_step/sec: 48.1437
# INFO:tensorflow:loss = 0.033763956, step = 33000 (2.077 sec)
# INFO:tensorflow:global_step/sec: 48.2969
# INFO:tensorflow:loss = 0.028688602, step = 33100 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.3209
# INFO:tensorflow:loss = 0.05803115, step = 33200 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.3096
# INFO:tensorflow:loss = 0.028865263, step = 33300 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.3545
# INFO:tensorflow:loss = 0.04833648, step = 33400 (2.068 sec)
# INFO:tensorflow:global_step/sec: 48.1072
# INFO:tensorflow:loss = 0.060298488, step = 33500 (2.079 sec)
# INFO:tensorflow:global_step/sec: 48.1712
# INFO:tensorflow:loss = 0.061400242, step = 33600 (2.077 sec)
# INFO:tensorflow:global_step/sec: 48.2663
# INFO:tensorflow:loss = 0.028711623, step = 33700 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.226
# INFO:tensorflow:loss = 0.041185055, step = 33800 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.307
# INFO:tensorflow:loss = 0.040565215, step = 33900 (2.071 sec)
# INFO:tensorflow:global_step/sec: 47.8254
# INFO:tensorflow:loss = 0.029768443, step = 34000 (2.091 sec)
# INFO:tensorflow:global_step/sec: 48.341
# INFO:tensorflow:loss = 0.048919693, step = 34100 (2.068 sec)
# INFO:tensorflow:global_step/sec: 48.3943
# INFO:tensorflow:loss = 0.08628407, step = 34200 (2.066 sec)
# INFO:tensorflow:global_step/sec: 48.0437
# INFO:tensorflow:loss = 0.024586653, step = 34300 (2.082 sec)
# INFO:tensorflow:global_step/sec: 48.2915
# INFO:tensorflow:loss = 0.059734765, step = 34400 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.2162
# INFO:tensorflow:loss = 0.0848806, step = 34500 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.148
# INFO:tensorflow:loss = 0.03220361, step = 34600 (2.077 sec)
# INFO:tensorflow:global_step/sec: 48.2749
# INFO:tensorflow:loss = 0.067854606, step = 34700 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.1217
# INFO:tensorflow:loss = 0.030570654, step = 34800 (2.079 sec)
# INFO:tensorflow:global_step/sec: 48.3624
# INFO:tensorflow:loss = 0.03379418, step = 34900 (2.067 sec)
# INFO:tensorflow:global_step/sec: 48.3238
# INFO:tensorflow:loss = 0.031147316, step = 35000 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.4938
# INFO:tensorflow:loss = 0.05300676, step = 35100 (2.062 sec)
# INFO:tensorflow:global_step/sec: 48.142
# INFO:tensorflow:loss = 0.05785814, step = 35200 (2.077 sec)
# INFO:tensorflow:global_step/sec: 48.1693
# INFO:tensorflow:loss = 0.044320658, step = 35300 (2.076 sec)
# INFO:tensorflow:global_step/sec: 48.4611
# INFO:tensorflow:loss = 0.02179168, step = 35400 (2.064 sec)
# INFO:tensorflow:global_step/sec: 48.3219
# INFO:tensorflow:loss = 0.033291917, step = 35500 (2.069 sec)
# INFO:tensorflow:global_step/sec: 47.8665
# INFO:tensorflow:loss = 0.067183614, step = 35600 (2.091 sec)
# INFO:tensorflow:global_step/sec: 47.9901
# INFO:tensorflow:loss = 0.072730854, step = 35700 (2.082 sec)
# INFO:tensorflow:global_step/sec: 48.4386
# INFO:tensorflow:loss = 0.027986612, step = 35800 (2.064 sec)
# INFO:tensorflow:global_step/sec: 48.3449
# INFO:tensorflow:loss = 0.031983003, step = 35900 (2.068 sec)
# INFO:tensorflow:global_step/sec: 48.3876
# INFO:tensorflow:loss = 0.090954475, step = 36000 (2.067 sec)
# INFO:tensorflow:global_step/sec: 48.2383
# INFO:tensorflow:loss = 0.070410736, step = 36100 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.4509
# INFO:tensorflow:loss = 0.055883262, step = 36200 (2.064 sec)
# INFO:tensorflow:global_step/sec: 48.4702
# INFO:tensorflow:loss = 0.026945952, step = 36300 (2.063 sec)
# INFO:tensorflow:global_step/sec: 48.2024
# INFO:tensorflow:loss = 0.040130414, step = 36400 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.4144
# INFO:tensorflow:loss = 0.03431102, step = 36500 (2.066 sec)
# INFO:tensorflow:global_step/sec: 48.3297
# INFO:tensorflow:loss = 0.046605524, step = 36600 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.1569
# INFO:tensorflow:loss = 0.06128079, step = 36700 (2.077 sec)
# INFO:tensorflow:global_step/sec: 48.3553
# INFO:tensorflow:loss = 0.030954268, step = 36800 (2.068 sec)
# INFO:tensorflow:global_step/sec: 48.2757
# INFO:tensorflow:loss = 0.043856613, step = 36900 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.1463
# INFO:tensorflow:loss = 0.020843787, step = 37000 (2.078 sec)
# INFO:tensorflow:global_step/sec: 48.0857
# INFO:tensorflow:loss = 0.03169833, step = 37100 (2.080 sec)
# INFO:tensorflow:global_step/sec: 48.2661
# INFO:tensorflow:loss = 0.06730705, step = 37200 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.1925
# INFO:tensorflow:loss = 0.024076667, step = 37300 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.202
# INFO:tensorflow:loss = 0.06421014, step = 37400 (2.075 sec)
# INFO:tensorflow:global_step/sec: 48.3265
# INFO:tensorflow:loss = 0.02866292, step = 37500 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.4211
# INFO:tensorflow:loss = 0.054669127, step = 37600 (2.064 sec)
# INFO:tensorflow:global_step/sec: 48.2627
# INFO:tensorflow:loss = 0.030638281, step = 37700 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.2461
# INFO:tensorflow:loss = 0.08708918, step = 37800 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.2017
# INFO:tensorflow:loss = 0.06988801, step = 37900 (2.075 sec)
# INFO:tensorflow:global_step/sec: 48.2975
# INFO:tensorflow:loss = 0.026347276, step = 38000 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.2539
# INFO:tensorflow:loss = 0.06575714, step = 38100 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.3606
# INFO:tensorflow:loss = 0.027700458, step = 38200 (2.068 sec)
# INFO:tensorflow:global_step/sec: 48.2359
# INFO:tensorflow:loss = 0.02715588, step = 38300 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.3938
# INFO:tensorflow:loss = 0.050917685, step = 38400 (2.066 sec)
# INFO:tensorflow:global_step/sec: 48.246
# INFO:tensorflow:loss = 0.03144432, step = 38500 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.2435
# INFO:tensorflow:loss = 0.023993248, step = 38600 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.2898
# INFO:tensorflow:loss = 0.0333815, step = 38700 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.1147
# INFO:tensorflow:loss = 0.051696382, step = 38800 (2.078 sec)
# INFO:tensorflow:global_step/sec: 48.375
# INFO:tensorflow:loss = 0.019459924, step = 38900 (2.067 sec)
# INFO:tensorflow:global_step/sec: 48.396
# INFO:tensorflow:loss = 0.020370333, step = 39000 (2.066 sec)
# INFO:tensorflow:global_step/sec: 48.024
# INFO:tensorflow:loss = 0.021015588, step = 39100 (2.083 sec)
# INFO:tensorflow:global_step/sec: 48.173
# INFO:tensorflow:loss = 0.03317908, step = 39200 (2.076 sec)
# INFO:tensorflow:global_step/sec: 47.986
# INFO:tensorflow:loss = 0.05819428, step = 39300 (2.084 sec)
# INFO:tensorflow:global_step/sec: 48.3613
# INFO:tensorflow:loss = 0.018680561, step = 39400 (2.068 sec)
# INFO:tensorflow:global_step/sec: 48.1723
# INFO:tensorflow:loss = 0.03370356, step = 39500 (2.076 sec)
# INFO:tensorflow:global_step/sec: 48.0738
# INFO:tensorflow:loss = 0.03065458, step = 39600 (2.080 sec)
# INFO:tensorflow:global_step/sec: 48.0126
# INFO:tensorflow:loss = 0.02811987, step = 39700 (2.083 sec)
# INFO:tensorflow:global_step/sec: 48.3463
# INFO:tensorflow:loss = 0.040093888, step = 39800 (2.068 sec)
# INFO:tensorflow:global_step/sec: 47.9219
# INFO:tensorflow:loss = 0.04161949, step = 39900 (2.086 sec)
# INFO:tensorflow:global_step/sec: 48.3657
# INFO:tensorflow:loss = 0.046347484, step = 40000 (2.068 sec)
# INFO:tensorflow:global_step/sec: 48.1791
# INFO:tensorflow:loss = 0.02169854, step = 40100 (2.075 sec)
# INFO:tensorflow:global_step/sec: 48.461
# INFO:tensorflow:loss = 0.034276545, step = 40200 (2.064 sec)
# INFO:tensorflow:global_step/sec: 47.9352
# INFO:tensorflow:loss = 0.04547021, step = 40300 (2.088 sec)
# INFO:tensorflow:global_step/sec: 48.407
# INFO:tensorflow:loss = 0.022618208, step = 40400 (2.064 sec)
# INFO:tensorflow:global_step/sec: 48.0861
# INFO:tensorflow:loss = 0.025429215, step = 40500 (2.080 sec)
# INFO:tensorflow:global_step/sec: 48.2108
# INFO:tensorflow:loss = 0.038505908, step = 40600 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.1921
# INFO:tensorflow:loss = 0.04240165, step = 40700 (2.075 sec)
# INFO:tensorflow:global_step/sec: 48.3366
# INFO:tensorflow:loss = 0.13329767, step = 40800 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.2993
# INFO:tensorflow:loss = 0.034863435, step = 40900 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.4255
# INFO:tensorflow:loss = 0.028551262, step = 41000 (2.065 sec)
# INFO:tensorflow:global_step/sec: 48.0448
# INFO:tensorflow:loss = 0.061298314, step = 41100 (2.081 sec)
# INFO:tensorflow:global_step/sec: 48.3267
# INFO:tensorflow:loss = 0.029920626, step = 41200 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.3097
# INFO:tensorflow:loss = 0.043230645, step = 41300 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.2567
# INFO:tensorflow:loss = 0.028338905, step = 41400 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.0578
# INFO:tensorflow:loss = 0.019937536, step = 41500 (2.080 sec)
# INFO:tensorflow:global_step/sec: 47.8887
# INFO:tensorflow:loss = 0.053310256, step = 41600 (2.088 sec)
# INFO:tensorflow:global_step/sec: 48.2582
# INFO:tensorflow:loss = 0.054139264, step = 41700 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.3136
# INFO:tensorflow:loss = 0.046583377, step = 41800 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.281
# INFO:tensorflow:loss = 0.036568653, step = 41900 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.1443
# INFO:tensorflow:loss = 0.06286191, step = 42000 (2.077 sec)
# INFO:tensorflow:global_step/sec: 48.4555
# INFO:tensorflow:loss = 0.020554377, step = 42100 (2.064 sec)
# INFO:tensorflow:global_step/sec: 48.0722
# INFO:tensorflow:loss = 0.0695893, step = 42200 (2.080 sec)
# INFO:tensorflow:global_step/sec: 48.4285
# INFO:tensorflow:loss = 0.042203665, step = 42300 (2.064 sec)
# INFO:tensorflow:global_step/sec: 48.415
# INFO:tensorflow:loss = 0.020016242, step = 42400 (2.065 sec)
# INFO:tensorflow:global_step/sec: 48.1853
# INFO:tensorflow:loss = 0.021586435, step = 42500 (2.075 sec)
# INFO:tensorflow:global_step/sec: 48.2747
# INFO:tensorflow:loss = 0.02410696, step = 42600 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.353
# INFO:tensorflow:loss = 0.01601619, step = 42700 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.2707
# INFO:tensorflow:loss = 0.015129925, step = 42800 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.215
# INFO:tensorflow:loss = 0.035659637, step = 42900 (2.074 sec)
# INFO:tensorflow:global_step/sec: 47.9533
# INFO:tensorflow:loss = 0.03305142, step = 43000 (2.085 sec)
# INFO:tensorflow:global_step/sec: 48.2814
# INFO:tensorflow:loss = 0.051118646, step = 43100 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.0369
# INFO:tensorflow:loss = 0.022805102, step = 43200 (2.081 sec)
# INFO:tensorflow:global_step/sec: 48.5669
# INFO:tensorflow:loss = 0.03408578, step = 43300 (2.059 sec)
# INFO:tensorflow:global_step/sec: 47.7751
# INFO:tensorflow:loss = 0.014869114, step = 43400 (2.093 sec)
# INFO:tensorflow:global_step/sec: 48.3054
# INFO:tensorflow:loss = 0.019762447, step = 43500 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.3568
# INFO:tensorflow:loss = 0.035467405, step = 43600 (2.068 sec)
# INFO:tensorflow:global_step/sec: 48.3216
# INFO:tensorflow:loss = 0.027849164, step = 43700 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.3312
# INFO:tensorflow:loss = 0.04876756, step = 43800 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.3262
# INFO:tensorflow:loss = 0.037470017, step = 43900 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.3263
# INFO:tensorflow:loss = 0.0252282, step = 44000 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.2926
# INFO:tensorflow:loss = 0.019024959, step = 44100 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.0997
# INFO:tensorflow:loss = 0.021961153, step = 44200 (2.079 sec)
# INFO:tensorflow:global_step/sec: 48.4076
# INFO:tensorflow:loss = 0.10356493, step = 44300 (2.066 sec)
# INFO:tensorflow:global_step/sec: 48.012
# INFO:tensorflow:loss = 0.017172566, step = 44400 (2.082 sec)
# INFO:tensorflow:global_step/sec: 48.3649
# INFO:tensorflow:loss = 0.05776374, step = 44500 (2.067 sec)
# INFO:tensorflow:global_step/sec: 48.2317
# INFO:tensorflow:loss = 0.016157156, step = 44600 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.2942
# INFO:tensorflow:loss = 0.033802953, step = 44700 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.3435
# INFO:tensorflow:loss = 0.032701854, step = 44800 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.3094
# INFO:tensorflow:loss = 0.027653433, step = 44900 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.2804
# INFO:tensorflow:loss = 0.038332086, step = 45000 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.1863
# INFO:tensorflow:loss = 0.021473758, step = 45100 (2.075 sec)
# INFO:tensorflow:global_step/sec: 48.198
# INFO:tensorflow:loss = 0.053421244, step = 45200 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.2186
# INFO:tensorflow:loss = 0.033663176, step = 45300 (2.075 sec)
# INFO:tensorflow:global_step/sec: 48.0346
# INFO:tensorflow:loss = 0.041340582, step = 45400 (2.081 sec)
# INFO:tensorflow:global_step/sec: 48.4702
# INFO:tensorflow:loss = 0.04015998, step = 45500 (2.063 sec)
# INFO:tensorflow:global_step/sec: 48.133
# INFO:tensorflow:loss = 0.015114244, step = 45600 (2.077 sec)
# INFO:tensorflow:global_step/sec: 48.3594
# INFO:tensorflow:loss = 0.028222328, step = 45700 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.1925
# INFO:tensorflow:loss = 0.036188148, step = 45800 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.3868
# INFO:tensorflow:loss = 0.015200233, step = 45900 (2.067 sec)
# ...
# INFO:tensorflow:global_step/sec: 48.2126
# INFO:tensorflow:loss = 0.035592377, step = 63600 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.2704
# INFO:tensorflow:loss = 0.013909963, step = 63700 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.2675
# INFO:tensorflow:loss = 0.040526472, step = 63800 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.425
# INFO:tensorflow:loss = 0.026114004, step = 63900 (2.065 sec)
# INFO:tensorflow:global_step/sec: 48.155
# INFO:tensorflow:loss = 0.037752997, step = 64000 (2.077 sec)
# INFO:tensorflow:global_step/sec: 48.0162
# INFO:tensorflow:loss = 0.011907402, step = 64100 (2.083 sec)
# INFO:tensorflow:global_step/sec: 48.4444
# INFO:tensorflow:loss = 0.01863725, step = 64200 (2.064 sec)
# INFO:tensorflow:global_step/sec: 48.5159
# INFO:tensorflow:loss = 0.030115973, step = 64300 (2.061 sec)
# INFO:tensorflow:global_step/sec: 48.5686
# INFO:tensorflow:loss = 0.014723932, step = 64400 (2.059 sec)
# INFO:tensorflow:global_step/sec: 48.055
# INFO:tensorflow:loss = 0.015802296, step = 64500 (2.081 sec)
# INFO:tensorflow:global_step/sec: 48.1174
# INFO:tensorflow:loss = 0.013082303, step = 64600 (2.079 sec)
# INFO:tensorflow:global_step/sec: 48.3086
# INFO:tensorflow:loss = 0.013537978, step = 64700 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.2722
# INFO:tensorflow:loss = 0.023393469, step = 64800 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.0818
# INFO:tensorflow:loss = 0.06008747, step = 64900 (2.080 sec)
# INFO:tensorflow:global_step/sec: 48.4092
# INFO:tensorflow:loss = 0.012481865, step = 65000 (2.066 sec)
# INFO:tensorflow:global_step/sec: 48.4531
# INFO:tensorflow:loss = 0.011977564, step = 65100 (2.064 sec)
# INFO:tensorflow:global_step/sec: 48.4753
# INFO:tensorflow:loss = 0.048684694, step = 65200 (2.063 sec)
# INFO:tensorflow:global_step/sec: 48.0392
# INFO:tensorflow:loss = 0.042536005, step = 65300 (2.081 sec)
# INFO:tensorflow:global_step/sec: 48.2126
# INFO:tensorflow:loss = 0.033264056, step = 65400 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.0023
# INFO:tensorflow:loss = 0.0330734, step = 65500 (2.083 sec)
# INFO:tensorflow:global_step/sec: 48.5529
# INFO:tensorflow:loss = 0.014497908, step = 65600 (2.060 sec)
# INFO:tensorflow:global_step/sec: 48.1698
# INFO:tensorflow:loss = 0.0156786, step = 65700 (2.077 sec)
# INFO:tensorflow:global_step/sec: 48.3873
# INFO:tensorflow:loss = 0.02212309, step = 65800 (2.066 sec)
# INFO:tensorflow:global_step/sec: 48.1635
# INFO:tensorflow:loss = 0.018274363, step = 65900 (2.076 sec)
# INFO:tensorflow:global_step/sec: 48.4184
# INFO:tensorflow:loss = 0.014330886, step = 66000 (2.068 sec)
# INFO:tensorflow:global_step/sec: 48.3175
# INFO:tensorflow:loss = 0.02048345, step = 66100 (2.067 sec)
# INFO:tensorflow:global_step/sec: 48.3131
# INFO:tensorflow:loss = 0.014752144, step = 66200 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.1683
# INFO:tensorflow:loss = 0.026186038, step = 66300 (2.076 sec)
# INFO:tensorflow:global_step/sec: 48.3694
# INFO:tensorflow:loss = 0.01479071, step = 66400 (2.068 sec)
# INFO:tensorflow:global_step/sec: 48.0463
# INFO:tensorflow:loss = 0.019850053, step = 66500 (2.080 sec)
# INFO:tensorflow:global_step/sec: 48.1547
# INFO:tensorflow:loss = 0.027193937, step = 66600 (2.077 sec)
# INFO:tensorflow:global_step/sec: 48.1994
# INFO:tensorflow:loss = 0.013568615, step = 66700 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.3178
# INFO:tensorflow:loss = 0.01794393, step = 66800 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.5094
# INFO:tensorflow:loss = 0.03627725, step = 66900 (2.061 sec)
# INFO:tensorflow:global_step/sec: 48.2186
# INFO:tensorflow:loss = 0.018191472, step = 67000 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.2325
# INFO:tensorflow:loss = 0.014232852, step = 67100 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.1475
# INFO:tensorflow:loss = 0.011949859, step = 67200 (2.077 sec)
# INFO:tensorflow:global_step/sec: 48.3937
# INFO:tensorflow:loss = 0.012667821, step = 67300 (2.067 sec)
# INFO:tensorflow:global_step/sec: 48.2086
# INFO:tensorflow:loss = 0.024171583, step = 67400 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.2174
# INFO:tensorflow:loss = 0.027426979, step = 67500 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.1697
# INFO:tensorflow:loss = 0.016594918, step = 67600 (2.076 sec)
# INFO:tensorflow:global_step/sec: 48.3048
# INFO:tensorflow:loss = 0.046144515, step = 67700 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.3743
# INFO:tensorflow:loss = 0.024682945, step = 67800 (2.068 sec)
# INFO:tensorflow:global_step/sec: 48.2194
# INFO:tensorflow:loss = 0.04214301, step = 67900 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.2654
# INFO:tensorflow:loss = 0.02127241, step = 68000 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.2686
# INFO:tensorflow:loss = 0.018123081, step = 68100 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.3049
# INFO:tensorflow:loss = 0.03755185, step = 68200 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.1876
# INFO:tensorflow:loss = 0.021143496, step = 68300 (2.075 sec)
# INFO:tensorflow:global_step/sec: 48.2914
# INFO:tensorflow:loss = 0.013883555, step = 68400 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.2744
# INFO:tensorflow:loss = 0.01645201, step = 68500 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.0912
# INFO:tensorflow:loss = 0.05480719, step = 68600 (2.079 sec)
# INFO:tensorflow:global_step/sec: 48.4385
# INFO:tensorflow:loss = 0.014034441, step = 68700 (2.065 sec)
# INFO:tensorflow:global_step/sec: 48.2466
# INFO:tensorflow:loss = 0.017399272, step = 68800 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.18
# INFO:tensorflow:loss = 0.012671387, step = 68900 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.1969
# INFO:tensorflow:loss = 0.02685745, step = 69000 (2.075 sec)
# INFO:tensorflow:global_step/sec: 48.4325
# INFO:tensorflow:loss = 0.013370993, step = 69100 (2.065 sec)
# INFO:tensorflow:global_step/sec: 48.2562
# INFO:tensorflow:loss = 0.015451487, step = 69200 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.1511
# INFO:tensorflow:loss = 0.032258682, step = 69300 (2.077 sec)
# INFO:tensorflow:global_step/sec: 48.1865
# INFO:tensorflow:loss = 0.024536429, step = 69400 (2.075 sec)
# INFO:tensorflow:global_step/sec: 48.2877
# INFO:tensorflow:loss = 0.014756685, step = 69500 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.1777
# INFO:tensorflow:loss = 0.02292012, step = 69600 (2.076 sec)
# INFO:tensorflow:global_step/sec: 48.3006
# INFO:tensorflow:loss = 0.027618954, step = 69700 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.2381
# INFO:tensorflow:loss = 0.01865134, step = 69800 (2.075 sec)
# INFO:tensorflow:global_step/sec: 48.3863
# INFO:tensorflow:loss = 0.018065404, step = 69900 (2.066 sec)
# INFO:tensorflow:global_step/sec: 48.0688
# INFO:tensorflow:loss = 0.012509402, step = 70000 (2.080 sec)
# INFO:tensorflow:global_step/sec: 48.218
# INFO:tensorflow:loss = 0.016086426, step = 70100 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.1138
# INFO:tensorflow:loss = 0.01573166, step = 70200 (2.079 sec)
# INFO:tensorflow:global_step/sec: 48.6011
# INFO:tensorflow:loss = 0.016669165, step = 70300 (2.057 sec)
# INFO:tensorflow:global_step/sec: 48.0552
# INFO:tensorflow:loss = 0.026529398, step = 70400 (2.081 sec)
# INFO:tensorflow:global_step/sec: 48.3065
# INFO:tensorflow:loss = 0.022708628, step = 70500 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.3932
# INFO:tensorflow:loss = 0.022617687, step = 70600 (2.066 sec)
# INFO:tensorflow:global_step/sec: 48.0573
# INFO:tensorflow:loss = 0.014495529, step = 70700 (2.081 sec)
# INFO:tensorflow:global_step/sec: 48.0456
# INFO:tensorflow:loss = 0.031842627, step = 70800 (2.081 sec)
# INFO:tensorflow:global_step/sec: 48.318
# INFO:tensorflow:loss = 0.026035858, step = 70900 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.3434
# INFO:tensorflow:loss = 0.046678625, step = 71000 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.3588
# INFO:tensorflow:loss = 0.013140224, step = 71100 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.3253
# INFO:tensorflow:loss = 0.019197065, step = 71200 (2.068 sec)
# INFO:tensorflow:global_step/sec: 48.1363
# INFO:tensorflow:loss = 0.023815174, step = 71300 (2.077 sec)
# INFO:tensorflow:global_step/sec: 48.0821
# INFO:tensorflow:loss = 0.014939394, step = 71400 (2.080 sec)
# INFO:tensorflow:global_step/sec: 47.9672
# INFO:tensorflow:loss = 0.029524136, step = 71500 (2.085 sec)
# INFO:tensorflow:global_step/sec: 48.4388
# INFO:tensorflow:loss = 0.025606897, step = 71600 (2.064 sec)
# INFO:tensorflow:global_step/sec: 48.4192
# INFO:tensorflow:loss = 0.011195252, step = 71700 (2.065 sec)
# INFO:tensorflow:global_step/sec: 48.1868
# INFO:tensorflow:loss = 0.019776184, step = 71800 (2.075 sec)
# INFO:tensorflow:global_step/sec: 47.9756
# INFO:tensorflow:loss = 0.012467096, step = 71900 (2.084 sec)
# INFO:tensorflow:global_step/sec: 48.2551
# INFO:tensorflow:loss = 0.03164988, step = 72000 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.2114
# INFO:tensorflow:loss = 0.013558835, step = 72100 (2.074 sec)
# INFO:tensorflow:global_step/sec: 47.9978
# INFO:tensorflow:loss = 0.01299284, step = 72200 (2.083 sec)
# INFO:tensorflow:global_step/sec: 47.9794
# INFO:tensorflow:loss = 0.011532036, step = 72300 (2.084 sec)
# INFO:tensorflow:global_step/sec: 48.206
# INFO:tensorflow:loss = 0.033928074, step = 72400 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.3112
# INFO:tensorflow:loss = 0.013200749, step = 72500 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.4916
# INFO:tensorflow:loss = 0.014941771, step = 72600 (2.063 sec)
# INFO:tensorflow:global_step/sec: 48.1764
# INFO:tensorflow:loss = 0.011529971, step = 72700 (2.076 sec)
# INFO:tensorflow:global_step/sec: 47.9991
# INFO:tensorflow:loss = 0.017725892, step = 72800 (2.085 sec)
# INFO:tensorflow:global_step/sec: 48.3304
# INFO:tensorflow:loss = 0.012223722, step = 72900 (2.067 sec)
# INFO:tensorflow:global_step/sec: 48.0267
# INFO:tensorflow:loss = 0.020063952, step = 73000 (2.083 sec)
# INFO:tensorflow:global_step/sec: 48.0771
# INFO:tensorflow:loss = 0.027632212, step = 73100 (2.080 sec)
# INFO:tensorflow:global_step/sec: 48.077
# INFO:tensorflow:loss = 0.019532619, step = 73200 (2.080 sec)
# INFO:tensorflow:global_step/sec: 48.0334
# INFO:tensorflow:loss = 0.015385034, step = 73300 (2.083 sec)
# INFO:tensorflow:global_step/sec: 48.2413
# INFO:tensorflow:loss = 0.018262904, step = 73400 (2.072 sec)
# INFO:tensorflow:global_step/sec: 47.7999
# INFO:tensorflow:loss = 0.022400955, step = 73500 (2.092 sec)
# INFO:tensorflow:global_step/sec: 48.4292
# INFO:tensorflow:loss = 0.012278317, step = 73600 (2.064 sec)
# INFO:tensorflow:global_step/sec: 48.2581
# INFO:tensorflow:loss = 0.029156215, step = 73700 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.4185
# INFO:tensorflow:loss = 0.020565815, step = 73800 (2.065 sec)
# INFO:tensorflow:global_step/sec: 48.1109
# INFO:tensorflow:loss = 0.029764306, step = 73900 (2.079 sec)
# INFO:tensorflow:global_step/sec: 48.4091
# INFO:tensorflow:loss = 0.029084306, step = 74000 (2.066 sec)
# INFO:tensorflow:global_step/sec: 48.27
# INFO:tensorflow:loss = 0.010984475, step = 74100 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.3352
# INFO:tensorflow:loss = 0.04555735, step = 74200 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.0534
# INFO:tensorflow:loss = 0.016736701, step = 74300 (2.081 sec)
# INFO:tensorflow:global_step/sec: 48.3488
# INFO:tensorflow:loss = 0.034033388, step = 74400 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.3701
# INFO:tensorflow:loss = 0.012506987, step = 74500 (2.067 sec)
# INFO:tensorflow:global_step/sec: 48.3757
# INFO:tensorflow:loss = 0.026997957, step = 74600 (2.067 sec)
# INFO:tensorflow:global_step/sec: 48.0107
# INFO:tensorflow:loss = 0.01285029, step = 74700 (2.086 sec)
# INFO:tensorflow:global_step/sec: 48.2096
# INFO:tensorflow:loss = 0.011723033, step = 74800 (2.072 sec)
# INFO:tensorflow:global_step/sec: 48.2376
# INFO:tensorflow:loss = 0.015268642, step = 74900 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.4991
# INFO:tensorflow:loss = 0.011980267, step = 75000 (2.062 sec)
# INFO:tensorflow:global_step/sec: 48.42
# INFO:tensorflow:loss = 0.023488112, step = 75100 (2.065 sec)
# INFO:tensorflow:global_step/sec: 48.2348
# INFO:tensorflow:loss = 0.036859877, step = 75200 (2.074 sec)
# INFO:tensorflow:global_step/sec: 48.4875
# INFO:tensorflow:loss = 0.033311885, step = 75300 (2.062 sec)
# INFO:tensorflow:global_step/sec: 48.1331
# INFO:tensorflow:loss = 0.013585914, step = 75400 (2.077 sec)
# INFO:tensorflow:global_step/sec: 48.2856
# INFO:tensorflow:loss = 0.014751833, step = 75500 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.5136
# INFO:tensorflow:loss = 0.046610318, step = 75600 (2.062 sec)
# INFO:tensorflow:global_step/sec: 48.1908
# INFO:tensorflow:loss = 0.01515321, step = 75700 (2.075 sec)
# INFO:tensorflow:global_step/sec: 47.9842
# INFO:tensorflow:loss = 0.015894713, step = 75800 (2.084 sec)
# INFO:tensorflow:global_step/sec: 48.0516
# INFO:tensorflow:loss = 0.014944766, step = 75900 (2.081 sec)
# INFO:tensorflow:global_step/sec: 48.2242
# INFO:tensorflow:loss = 0.021982439, step = 76000 (2.073 sec)
# INFO:tensorflow:global_step/sec: 48.1989
# INFO:tensorflow:loss = 0.011056233, step = 76100 (2.075 sec)
# INFO:tensorflow:global_step/sec: 47.9803
# INFO:tensorflow:loss = 0.019856894, step = 76200 (2.084 sec)
# INFO:tensorflow:global_step/sec: 48.0854
# INFO:tensorflow:loss = 0.015243641, step = 76300 (2.080 sec)
# INFO:tensorflow:global_step/sec: 48.3152
# INFO:tensorflow:loss = 0.020039279, step = 76400 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.3032
# INFO:tensorflow:loss = 0.03767023, step = 76500 (2.071 sec)
# INFO:tensorflow:global_step/sec: 48.1636
# INFO:tensorflow:loss = 0.024349753, step = 76600 (2.076 sec)
# INFO:tensorflow:global_step/sec: 48.1548
# INFO:tensorflow:loss = 0.027467843, step = 76700 (2.076 sec)
# INFO:tensorflow:global_step/sec: 48.4934
# INFO:tensorflow:loss = 0.014816846, step = 76800 (2.062 sec)
# INFO:tensorflow:global_step/sec: 48.3526
# INFO:tensorflow:loss = 0.019401316, step = 76900 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.0842
# INFO:tensorflow:loss = 0.021012401, step = 77000 (2.079 sec)
# INFO:tensorflow:global_step/sec: 48.1303
# INFO:tensorflow:loss = 0.024334092, step = 77100 (2.078 sec)
# INFO:tensorflow:global_step/sec: 47.8446
# INFO:tensorflow:loss = 0.014671831, step = 77200 (2.090 sec)
# INFO:tensorflow:global_step/sec: 48.4539
# INFO:tensorflow:loss = 0.018288894, step = 77300 (2.064 sec)
# INFO:tensorflow:global_step/sec: 48.0264
# INFO:tensorflow:loss = 0.014209161, step = 77400 (2.082 sec)
# INFO:tensorflow:global_step/sec: 48.4564
# INFO:tensorflow:loss = 0.013724539, step = 77500 (2.064 sec)
# INFO:tensorflow:global_step/sec: 48.3666
# INFO:tensorflow:loss = 0.023606727, step = 77600 (2.067 sec)
# INFO:tensorflow:global_step/sec: 48.0051
# INFO:tensorflow:loss = 0.0113368, step = 77700 (2.083 sec)
# INFO:tensorflow:global_step/sec: 48.111
# INFO:tensorflow:loss = 0.032707535, step = 77800 (2.078 sec)
# INFO:tensorflow:global_step/sec: 48.3195
# INFO:tensorflow:loss = 0.01945161, step = 77900 (2.070 sec)
# INFO:tensorflow:global_step/sec: 48.327
# INFO:tensorflow:loss = 0.0432741, step = 78000 (2.069 sec)
# INFO:tensorflow:global_step/sec: 48.0659
# INFO:tensorflow:loss = 0.012196301, step = 78100 (2.080 sec)
# INFO:tensorflow:Saving checkpoints for 78200 into /data/jwfromm/cifar_models/vgg_baseline_full/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-04-20:29:53
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /data/jwfromm/cifar_models/vgg_baseline_full/model.ckpt-78200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Finished evaluation at 2019-04-04-20:29:55
# INFO:tensorflow:Saving dict for global step 78200: accuracy = 0.8874, global_step = 78200, loss = 0.5493577
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 78200: /data/jwfromm/cifar_models/vgg_baseline_full/model.ckpt-78200
# INFO:tensorflow:Loss for final step: 0.012119375.
# ({'accuracy': 0.8874, 'loss': 0.5493577, 'global_step': 78200}, [])
